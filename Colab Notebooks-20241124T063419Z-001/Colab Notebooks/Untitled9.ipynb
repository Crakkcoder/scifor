# %%
for i in range(1,11):
    if i % 3 == 0:
        continue # skip the number 3
    if i % 5 == 0:
        break # stop the loop when i is 5
    print(i)
# Out:
# 1
# 2
# 4

# %%
numbers = [1,-2,3,-4,5]
for num in numbers:
    if num < 0:
       print(f"First negative number: {num}")
       break
# Out:
# First negative number: -2

# %%
import barcode
from barcode.
# Out:
# Total sum of non-negative numbers is:
