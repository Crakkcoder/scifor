# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-5a6d2e1d9698> in <cell line: 34>()
#      32
#      33 # Create the main window
# ---> 34 root = tk.TK()
#      35 root.title("Registration form")
#      36
#
# AttributeError: module 'tkinter' has no attribute 'TK'
