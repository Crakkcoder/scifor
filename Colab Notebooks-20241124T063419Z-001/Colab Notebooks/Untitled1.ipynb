# %%
a = [1,2,3]
my_list = a.copy()
print(my_list)
# Out:
# [1, 2, 3]

# %%
a = ("apple","banana","cherry")
my_tuple = tuple(a)
print(my_tuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
x = "priyanka"
print(len(x))
# Out:
# 8

# %%
x = "priyanka"
printisupper(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c73874108a0a> in <cell line: 2>()
#       1 x = "priyanka"
# ----> 2 print(isupper(x))
#
# NameError: name 'isupper' is not defined
