# %%
num = int(input("enter a number:"))
temp=num
rev=0
while(num>0):
    dig=num%10
    rev=rev*10+dig
    num=num//10
if(temp==rev):
    print("the number is palindrome!")
else:
    print("the number is not palindrome!")
# Out:
# enter a number:95
# the number is not palindrome!

# %%
count = 0
for hours in range(24):
   for minutes in range(60):
      for seconds in range(60):
        count = count + 1
print("total numbers of combination",count)
# Out:
# total numbers of combination 86400
