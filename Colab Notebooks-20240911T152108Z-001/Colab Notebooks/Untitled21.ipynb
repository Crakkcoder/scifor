# %%
    """)

# Create the main window
root = tk.Tk()
root.title("COVID Vaccine Registration Form")

# Create and place labels and entries
tk.Label(root, text="Name of the visitor").grid(row=0, column=0, padx=10, pady=5, sticky="e")
name_entry = tk.Entry(root)
name_entry.grid(row=0, column=1, padx=10, pady=5)

tk.Label(root, text="Age of the visitor").grid(row=1, column=0, padx=10, pady=5, sticky="e")
age_entry = tk.Entry(root)
age_entry.grid(row=1, column=1, padx=10, pady=5)

tk.Label(root, text="Gender").grid(row=2, column=0, padx=10, pady=5, sticky="e")
gender_var = tk.StringVar()
tk.Radiobutton(root, text="Male", variable=gender_var, value="Male").grid(row=2, column=1, padx=10, pady=5, sticky="w")
tk.Radiobutton(root, text="Female", variable=gender_var, value="Female").grid(row=2, column=1, padx=10, pady=5)
tk.Radiobutton(root, text="Other", variable=gender_var, value="Other").grid(row=2, column=1, padx=10, pady=5)

tk.Label(root, text="Address").grid(row=3, column=0, padx=10, pady=5, sticky="e")
address_entry = tk.Entry(root)
address_entry.grid(row=3, column=1, padx=10, pady=5)

tk.Label(root, text="Email ID").grid(row=4, column=0, padx=10, pady=5, sticky="e")
email_entry = tk.Entry(root)
email_entry.grid(row=4, column=1, padx=10, pady=5)

tk.Label(root, text="Contact No").grid(row=5, column=0, padx=10, pady=5, sticky="e")
contact_no_entry = tk.Entry(root)
contact_no_entry.grid(row=5, column=1, padx=10, pady=5)

tk.Label(root, text="Country").grid(row=6, column=0, padx=10, pady=5, sticky="e")
country_entry = tk.Entry(root)
country_entry.grid(row=6, column=1, padx=10, pady=5)

tk.Label(root, text="State").grid(row=7, column=0, padx=10, pady=5, sticky="e")
state_entry = tk.Entry(root)
state_entry.grid(row=7, column=1, padx=10, pady=5)

tk.Label(root, text="Do you have any of the following diseases?").grid(row=8, column=0, padx=10, pady=5, sticky="e")
cold_var = tk.BooleanVar()
cough_var = tk.BooleanVar()
fever_var = tk.BooleanVar()
headache_var = tk.BooleanVar()
tk.Checkbutton(root, text="Cold", variable=cold_var).grid(row=8, column=1, padx=10, pady=5, sticky="w")
tk.Checkbutton(root, text="Cough", variable=cough_var).grid(row=8, column=1, padx=10, pady=5)
tk.Checkbutton(root, text="Fever", variable=fever_var).grid(row=8, column=1, padx=10, pady=5)
tk.Checkbutton(root, text="Headache", variable=headache_var).grid(row=8, column=1, padx=10, pady=5)

# Submit button
submit_button = tk.Button(root, text="Submit", command=submit_form)
submit_button.grid(row=9, column=1, padx=10, pady=10)

# Run the application
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-408387b9a1a8> in <cell line: 38>()
#      36
#      37 # Create the main window
# ---> 38 root = tk.Tk()
#      39 root.title("COVID Vaccine Registration Form")
#      40
#
# /usr/lib/python3.10/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2297                 baseName = baseName + ext
#    2298         interactive = False
# -> 2299         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2300         if useTk:
#    2301             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
